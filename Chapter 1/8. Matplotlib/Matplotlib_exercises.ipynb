# %% [markdown]
# # Matplotlib

# %% [markdown]
# For these exercises, we are using Pandas and Matplotlib to visualize Company Sales Data.
#
# We will be using the following dataset: https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv

# %% [markdown]
# ### Exercise 1: Read the Total profit of all months and show it using a line plot.
# Total profit data provided for each month. The enerated line plot must include the following properties:<br>
# - X label name = Month Number
# - Y label name = Total profit
#
# The line plot graph should look like this:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv('company_sales_data.csv')

plt.plot(df['month_number'],df['total_profit'],label='profit graph')

# %%
# Write your code here
url = 'https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv'

df = pd.read_csv('company_sales_data.csv')
fig,ax = plt.subplots()
plt.plot(df['month_number'],df['total_profit'],label='total profit',marker='o',c='r',linestyle='--',linewidth=3)
ax.set_xlabel('Month number')
ax.set_ylabel('Sold units number')
plt.legend(loc='lower right')
plt.title('company sales data of last year')
# Out:
# Text(0.5, 1.0, 'company sales data of last year')

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it using a multiline plot.
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product).
#
# The graph should look like this:
# ![image.png](attachment:image.png)

# %%
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
fig, ax = plt.subplots(figsize=(10,8))
plt.plot(df['month_number'],df['facecream'],label='facecream',marker="o")
plt.plot(df['month_number'],df['facewash'],label='facewash',marker="o")
plt.plot(df['month_number'],df['toothpaste'],label='toothpaste',marker='o')
plt.plot(df['month_number'],df['bathingsoap'],label='bathingsoap',marker='o')
plt.plot(df['month_number'],df['moisturizer'],label='moisturizer',marker='o')
plt.title('Sales data')
ax.set_xlabel("month number")
ax.set_ylabel("series in number")
plt.grid(True)
plt.legend()

# %% [markdown]
# ### Exercise 4: Read the toothpaste sales data of each month and show it using a scatter plot.
# Also, add a grid in the plot (the grid line style should be “–“).
#
# The scatter plot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here

fig ,ax = plt.subplots(figsize=(8,6))
plt.scatter(df['month_number'],df['toothpaste'])
ax.grid(linestyle='--')
ax.set_xlabel('month number')
ax.set_ylabel('number of unit sold')
plt.title('toothpaste sales data')
# Out:
# Text(0.5, 1.0, 'toothpaste sales data')

# %% [markdown]
# ### Exercise 5: Read the face cream and facewash product sales data and show it using the bar chart.
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fid,ax = plt.subplots(figsize=(10,8))
ax.bar(df['month_number']-0.3,df['facewash'],width=0.3,label='facewash')
ax.bar(df['month_number'],df['facecream'],width=0.3,label='face cream')
plt.grid(linestyle='--')
plt.legend()

# %% [markdown]
# ### Exercise 6: Read the sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk.
# The bar chart should look like this:
# ![image.png](attachment:image.png)

# %%
fig,ax = plt.subplots(figsize=(12,8))
plt.grid(linestyle='--')
ax.bar(df['month_number'],df['bathingsoap'])
plt.title('number of sales bathingsoap')
ax.set_xlabel('number of month')
ax.set_ylabel('sales')
plt.savefig('plot.png')

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges.
# The histogram should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig,ax = plt.subplots(figsize=(10,8))
plt.title('Profit data')
ax.set_xlabel('profit range in dollar')
ax.set_ylabel('actual profit in dollar')
ax.hist(df['total_profit'])
# Out:
# (array([2., 4., 1., 1., 1., 1., 0., 1., 0., 1.]),
#  array([183300., 206250., 229200., 252150., 275100., 298050., 321000.,
#         343950., 366900., 389850., 412800.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Exercise 8: Calculate the total sale data for last year for each product and show it using a Pie chart.
# Note: In the Pie chart you should display the Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig,ax = plt.subplots()
data =[df['facecream'].sum(),df['facewash'].sum(),df['toothpaste'].sum(),df['bathingsoap'].sum(),df['shampoo'].sum(),df['moisturizer'].sum()]
x= df.sum()[1:-2]
labels = df.columns[1:-2]
ax.pie(x,labels=labels,autopct='%.0f%%')
ax.axis('equal')
plt.legend(bbox_to_anchor=(1,0))

# %% [markdown]
# ### Exercise 9: Read the Bathing soap facewash of all months and display it using the Subplot.
# The Subplot should look like this:
# ![image.png](attachment:image.png)

# %%
# Write your code here
fig,ax = plt.subplots(2,1,figsize=(10,6))
ax[0].plot(df['month_number'],df['facewash'],c='r',linewidth=3,marker='^')
ax[1].plot(df['month_number'],df['bathingsoap'],c='r',linewidth=3,marker='^')
ax[0].set_title('facewash sales')
ax[0].set_xlabel('number of month')
ax[0].set_ylabel('sale units in number')
ax[1].set_title('bathing soap sales')
ax[1].set_xlabel('number of month')
ax[1].set_ylabel('sales unit in number')


fig.tight_layout()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot.
# The Stack plot should look like this:
# ![image.png](attachment:image.png)

# %%
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
# Write your code here
x= df['month_number']
y1,y2,y3,y4,y5,y6 = df['facecream'],df['facewash'],df['toothpaste'],df['bathingsoap'],df['shampoo'],df['moisturizer']
fig,ax = plt.subplots(figsize=(12,8))
ax.set_xlabel('number of month')
ax.set_ylabel('total sales')
ax.set_title('all products sales')
color_map = ['#B4B5BE','#333738','#B18742','#635B6C','#6F313C','#814B38']

ax.stackplot(x,y1,y2,y3,y4,y5,y6,labels =df.columns[1:-2],colors=color_map)
plt.legend(loc='upper left')
