# %%
import torch
from torch import nn 
from torch.utils.data import DataLoader,Dataset
import torch.nn.functional as F
import numpy as np 
import spacy

# %% [markdown]
# ## chats

# %%
chats = {'intents':
    [
        {
            'tag':'Greeting',
            'patterns':[
                'Hi',
                'Hey!',
                'Hello!',
                'Good morning',
                'Good day',
                'good evening'
            ],
            'responses':[
                'Hey! Nice to have you here. How can I help you ?',
                'Hi, how can I help you ?',
                'Hello, thank you for visiting us. How can I help you?',
                'Good day, I am here to help you.'
            ]
        },
        {
            'tag':'Bye',
            'patterns':
            [
                'Bye',
                'See you later',
                'Have a good one',
                'Have a nice day',
                'Good bye'
            ],
            'responses':[
                'You too.',
                'Have a good one.',
                'Have a nice day'
            ]
        },
        {
            'tag':'Thanks',
            'patterns':[
                'Thanks',
                'Thank you',
                "Thanks, that's helpful!"
            ],
            'responses':[
                'Happy to help you',
                'My pleasure'
            ]
        },
        {
            'tag':'Feeling',
            'patterns':[
                "I don't feel well today",
                "I am exausted, I don't know what's wrong",
                "Something wrong with me"
            ],
            'responses':[
                "Can you tell me if you have any symtom?",
                "Do you have any symtoms?",
                "What kind of symtoms do you have?"
            ]
        },
        {
            'tag':'Symtoms',
            'patterns':[
                'I have high temperature',
                'I have headache',
                'I have temperature and nausea',
                'I a dry cough and temperature'
            ],
            'responses':[
                'Okay, you should get consulted. Do you want to book an appointment?',
                'Do you want me to book an appointment for you?',
                'Symtoms can be sign of multiple things, to diagnosis we need some tests. Do you want an anppointment booked ?'
            ]
        },
        {
            'tag':'Appoinment',
            'patterns':[
                'yes please, for tomorrow',
                'yes, if possible, tomorrow',
                'for tomorrow, please',
            ],
            'responses':[
                'Okay, your appoinment is for tomorrow',
                "you can come tomorrow",
                "okay, it has been done for you!"

            ]
        }
    ]
}

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### tokenize

# %%
def tokenizer(sentence):
    doc = nlp(sentence)
    tokens = [token.lemma_ for token in doc if not token.is_punct]
    return tokens

# %%
def prep():
   tags = []
   patterns = []
   voca = []
   pairs = []
   for intent in chats['intents']:
      tags.append(intent['tag'])
      for pattern in intent['patterns']:
         tokens = tokenizer(pattern)
         w = [token for token in tokens if not token in voca]
         voca.extend(w)
         pairs.append((tokens,intent['tag']))
   print(f'tags-{tags}')
   print(f'vocab size-{len(voca)}')
   print(f'{pairs}')
   return pairs,voca,tags

# %%
pairs,voca,tags = prep()
# Out:
# tags-['Greeting', 'Bye', 'Thanks', 'Feeling', 'Symtoms', 'Appoinment']
# vocab size-44
# [(['hi'], 'Greeting'), (['hey'], 'Greeting'), (['hello'], 'Greeting'), (['good', 'morning'], 'Greeting'), (['good', 'day'], 'Greeting'), (['good', 'evening'], 'Greeting'), (['bye'], 'Bye'), (['see', 'you', 'later'], 'Bye'), (['have', 'a', 'good', 'one'], 'Bye'), (['have', 'a', 'nice', 'day'], 'Bye'), (['good', 'bye'], 'Bye'), (['thank'], 'Thanks'), (['thank', 'you'], 'Thanks'), (['thank', 'that', 'be', 'helpful'], 'Thanks'), (['I', 'do', 'not', 'feel', 'well', 'today'], 'Feeling'), (['I', 'be', 'exauste', 'I', 'do', 'not', 'know', 'what', 'be', 'wrong'], 'Feeling'), (['something', 'wrong', 'with', 'I'], 'Feeling'), (['I', 'have', 'high', 'temperature'], 'Symtoms'), (['I', 'have', 'headache'], 'Symtoms'), (['I', 'have', 'temperature', 'and', 'nausea'], 'Symtoms'), (['I', 'a', 'dry', 'cough', 'and', 'temperature'], 'Symtoms'), (['yes', 'please', 'for', 'tomorrow'], 'Appoinment'), (['yes', 'if', 'possible', 'tomorrow'], 'Appoinment'), (['for', 'tomorrow', 'please'], 'Appoinment')]

# %%
def embed(voca,sentence):
    '''
     1 for each known word that exists in the sentence, 0 otherwise
    example:
    sentence = ["hello", "how", "are", "you"]
    words = ["hi", "hello", "I", "you", "bye", "thank", "cool"]
    bag   = [  0 ,    1 ,    0 ,   1 ,    0 ,    0 ,      0]
    '''
    bag =np.zeros(len(voca),dtype=np.float32)
    for idx,w in enumerate(voca):
        if w in sentence:
            bag[idx] += 1
    return bag

# %%
def tokenize(pairs,voca,tags):
    xs = []
    labels = []
    for pair in pairs:
        # getting x and labels
        x,y = pair

        #embedding
        x = embed(voca,x)
        y = tags.index(y)
        xs.append(x)
        labels.append(y)
    return xs,labels

# %%
x,label = tokenize(pairs,voca,tags)

# %% [markdown]
# ## dataset and dataloader

# %%
class CusDatset(Dataset):
    def __init__(self,xs,labels):
        self.len = len(xs)
        self.xs = xs
        self.labels = labels

    def __getitem__(self,ind):
        return self.xs[ind],self.labels[ind]
    def __len__(self):
        return self.len

# %%
batchsize =2
trainset = CusDatset(x,label)
trainloader = DataLoader(trainset,batch_size=batchsize,shuffle=True)

# %%
x,y  =  iter(trainloader).next()

# %% [markdown]
# ## model

# %%
class Model(nn.Module):
    def __init__(self,in_dim,hidden1,hidden2,out_dim):
        super(Model,self).__init__()
        self.fc1 = nn.Linear(in_dim,hidden1)
        self.fc2 = nn.Linear(hidden1,hidden2)
        self.fc3 = nn.Linear(hidden2,out_dim)
    
    def forward(self,x):
        z = F.relu(self.fc1(x))
        z = F.relu(self.fc2(z))
        out = self.fc3(z)

        return out

# %%
input_size = len(voca)
out_size = len(tags)
model = Model(input_size,20,10,out_size)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.003)
epochs = 500

for epoch in range(epochs):
    losses = []
    print(f'running {epoch+1} out of {epochs} epochs')

    for x,y in trainloader:
        optimizer.zero_grad()
        y = torch.tensor(y,dtype=torch.long)
        x = torch.tensor(x,dtype=torch.float)
        out = model.forward(x)
        loss = criterion(out,y)
        loss.backward()
        optimizer.step()
        losses.append(loss.item())


    print(np.mean(losses))
torch.save(model.state_dict(),'med_bot.pth')
# Out:
# running 1 out of 500 epochs
# 1.8045118749141693
# running 2 out of 500 epochs
# 1.7800026436646779
# running 3 out of 500 epochs
# 1.7563117643197377
# running 4 out of 500 epochs
# 1.7162188192208607
# running 5 out of 500 epochs
# 1.668918530146281
# running 6 out of 500 epochs
# 1.593627045551936
# running 7 out of 500 epochs
# 1.488975505034129
# running 8 out of 500 epochs
# 1.3657416999340057
# running 9 out of 500 epochs
# 1.2304579267899196
# running 10 out of 500 epochs
# 1.0858807439605396
# running 11 out of 500 epochs
# 0.9469087471564611
# running 12 out of 500 epochs
# 0.82232582817475
# running 13 out of 500 epochs
# 0.7036415586868922
# running 14 out of 500 epochs
# 0.5961002732316653
# running 15 out of 500 epochs
# 0.490581420250237
# running 16 out of 500 epochs
# 0.38751585098604363
# running 17 out of 500 epochs
# 0.3088924443970124
# running 18 out of 500 epochs
# 0.23705330056448778
# running 19 out of 500 epochs
# 0.18198983774830899
# running 20 out of 500 epochs
# 0.14210659001643458
# running 21 out of 500 epochs
# 0.11134172743186355
# running 22 out of 500 epochs
# 0.0881043264331917
# running 23 out of 500 epochs
# 0.07113918537894885
# running 24 out of 500 epochs
# 0.05775178627421459
# running 25 out of 500 epochs
# 0.047933975545068584
# running 26 out of 500 epochs
# 0.04094699940954646
# running 27 out of 500 epochs
# 0.034645669627934694
# running 28 out of 500 epochs
# 0.02986767509719357
# running 29 out of 500 epochs
# 0.026223162266736228
# running 30 out of 500 epochs
# 0.023503022268414497
# running 31 out of 500 epochs
# /var/folders/1h/x7tmv9xd1bsclx868ql32nf40000gn/T/ipykernel_44657/2523379147.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(y,dtype=torch.long)
# /var/folders/1h/x7tmv9xd1bsclx868ql32nf40000gn/T/ipykernel_44657/2523379147.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x,dtype=torch.float)
# 0.020877829131980736
# running 32 out of 500 epochs
# 0.01861481830322494
# running 33 out of 500 epochs
# 0.016887386368277173
# running 34 out of 500 epochs
# 0.015182323365782699
# running 35 out of 500 epochs
# 0.013727629596057037
# running 36 out of 500 epochs
# 0.012744173310541859
# running 37 out of 500 epochs
# 0.011753778846468776
# running 38 out of 500 epochs
# 0.0108133289613761
# running 39 out of 500 epochs
# 0.009999400392795602
# running 40 out of 500 epochs
# 0.009254374036875864
# running 41 out of 500 epochs
# 0.00867573160212487
# running 42 out of 500 epochs
# 0.008102849106459567
# running 43 out of 500 epochs
# 0.007577283094481875
# running 44 out of 500 epochs
# 0.007170908017239223
# running 45 out of 500 epochs
# 0.006697013314502935
# running 46 out of 500 epochs
# 0.006321514869341627
# running 47 out of 500 epochs
# 0.005955698269341762
# running 48 out of 500 epochs
# 0.005669467383995652
# running 49 out of 500 epochs
# 0.005353102809749544
# running 50 out of 500 epochs
# 0.005070032755611464
# running 51 out of 500 epochs
# 0.004828005248176244
# running 52 out of 500 epochs
# 0.004567847286428635
# running 53 out of 500 epochs
# 0.0043962158912715195
# running 54 out of 500 epochs
# 0.004168467571920094
# running 55 out of 500 epochs
# 0.003983474996251364
# running 56 out of 500 epochs
# 0.0038046814831128963
# running 57 out of 500 epochs
# 0.0036525398657734818
# running 58 out of 500 epochs
# 0.0034771992310804003
# running 59 out of 500 epochs
# 0.0033433114246387654
# running 60 out of 500 epochs
# 0.003207410617809122
# running 61 out of 500 epochs
# 0.003092664381256327
# running 62 out of 500 epochs
# 0.002961471376086896
# running 63 out of 500 epochs
# 0.002850571550273647
# running 64 out of 500 epochs
# 0.0027360100308821225
# running 65 out of 500 epochs
# 0.0026437212194044455
# running 66 out of 500 epochs
# 0.002543239723308943
# running 67 out of 500 epochs
# 0.002457381876107926
# running 68 out of 500 epochs
# 0.002366833713798163
# running 69 out of 500 epochs
# 0.0022914951308242357
# running 70 out of 500 epochs
# 0.002211658594508966
# running 71 out of 500 epochs
# 0.00213858649173441
# running 72 out of 500 epochs
# 0.0020636803261974515
# running 73 out of 500 epochs
# 0.0020000576453943117
# running 74 out of 500 epochs
# 0.0019386592175578699
# running 75 out of 500 epochs
# 0.0018817409290932119
# running 76 out of 500 epochs
# 0.001820365529662619
# running 77 out of 500 epochs
# 0.001763123330116893
# running 78 out of 500 epochs
# 0.0017148381666629575
# running 79 out of 500 epochs
# 0.001663291644945275
# running 80 out of 500 epochs
# 0.0016150444668407242
# running 81 out of 500 epochs
# 0.0015672293253980267
# running 82 out of 500 epochs
# 0.001524264895124361
# running 83 out of 500 epochs
# 0.0014885852676040183
# running 84 out of 500 epochs
# 0.0014411458105314523
# running 85 out of 500 epochs
# 0.001402714539532705
# running 86 out of 500 epochs
# 0.0013623477352666669
# running 87 out of 500 epochs
# 0.0013287319961818866
# running 88 out of 500 epochs
# 0.001296044664438038
# running 89 out of 500 epochs
# 0.0012599596605771997
# running 90 out of 500 epochs
# 0.0012297087111316312
# running 91 out of 500 epochs
# 0.0011988132100668736
# running 92 out of 500 epochs
# 0.001168841384545279
# running 93 out of 500 epochs
# 0.00113953473677005
# running 94 out of 500 epochs
# 0.001111083683402588
# running 95 out of 500 epochs
# 0.0010830552952635724
# running 96 out of 500 epochs
# 0.0010649605367992383
# running 97 out of 500 epochs
# 0.0010334199711602803
# running 98 out of 500 epochs
# 0.0010123128328511182
# running 99 out of 500 epochs
# 0.0009861733196885325
# running 100 out of 500 epochs
# 0.0009627761173760518
# running 101 out of 500 epochs
# 0.0009396922590288644
# running 102 out of 500 epochs
# 0.0009219219088360356
# running 103 out of 500 epochs
# 0.0008974617315592089
# running 104 out of 500 epochs
# 0.0008809272439975757
# running 105 out of 500 epochs
# 0.0008598127824370749
# running 106 out of 500 epochs
# 0.000842088199230299
# running 107 out of 500 epochs
# 0.0008223561041328745
# running 108 out of 500 epochs
# 0.000806657813276009
# running 109 out of 500 epochs
# 0.0007876043049085032
# running 110 out of 500 epochs
# 0.000771520055423025
# running 111 out of 500 epochs
# 0.0007563295924531607
# running 112 out of 500 epochs
# 0.0007406419851273919
# running 113 out of 500 epochs
# 0.0007264673380025973
# running 114 out of 500 epochs
# 0.0007119742634434564
# running 115 out of 500 epochs
# 0.0006973150672517173
# running 116 out of 500 epochs
# 0.0006830513696816828
# running 117 out of 500 epochs
# 0.000669423388899304
# running 118 out of 500 epochs
# 0.0006587127730502592
# running 119 out of 500 epochs
# 0.0006442857629735954
# running 120 out of 500 epochs
# 0.0006321772804464368
# running 121 out of 500 epochs
# 0.0006206138956864985
# running 122 out of 500 epochs
# 0.0006084976315226717
# running 123 out of 500 epochs
# 0.0005971719680625635
# running 124 out of 500 epochs
# 0.000586050441294598
# running 125 out of 500 epochs
# 0.0005749678069453997
# running 126 out of 500 epochs
# 0.0005648119082858708
# running 127 out of 500 epochs
# 0.0005548756489588413
# running 128 out of 500 epochs
# 0.0005444240038438389
# running 129 out of 500 epochs
# 0.0005358497219276614
# running 130 out of 500 epochs
# 0.000525094232216361
# running 131 out of 500 epochs
# 0.0005158562859530017
# running 132 out of 500 epochs
# 0.0005079161649822103
# running 133 out of 500 epochs
# 0.0004984265215171035
# running 134 out of 500 epochs
# 0.0004894460162176983
# running 135 out of 500 epochs
# 0.00048122405193377443
# running 136 out of 500 epochs
# 0.00047347843064926565
# running 137 out of 500 epochs
# 0.00046543489891822293
# running 138 out of 500 epochs
# 0.0004574859061297805
# running 139 out of 500 epochs
# 0.00045055266067114036
# running 140 out of 500 epochs
# 0.0004423165561699231
# running 141 out of 500 epochs
# 0.0004349228911451064
# running 142 out of 500 epochs
# 0.0004283523570241717
# running 143 out of 500 epochs
# 0.00042134488285228144
# running 144 out of 500 epochs
# 0.00041449688372570864
# running 145 out of 500 epochs
# 0.00040743566448024165
# running 146 out of 500 epochs
# 0.0004015347270372634
# running 147 out of 500 epochs
# 0.00039531095020114054
# running 148 out of 500 epochs
# 0.00038880015623969183
# running 149 out of 500 epochs
# 0.00038279514471165993
# running 150 out of 500 epochs
# 0.0003771567905156796
# running 151 out of 500 epochs
# 0.00037092876906778355
# running 152 out of 500 epochs
# 0.00036521610733567894
# running 153 out of 500 epochs
# 0.0003594342933865846
# running 154 out of 500 epochs
# 0.0003542227180635867
# running 155 out of 500 epochs
# 0.00034913522661857616
# running 156 out of 500 epochs
# 0.0003435219393092363
# running 157 out of 500 epochs
# 0.0003385140377455779
# running 158 out of 500 epochs
# 0.000333575225037445
# running 159 out of 500 epochs
# 0.0003285223441101455
# running 160 out of 500 epochs
# 0.00032429324892291334
# running 161 out of 500 epochs
# 0.00031907194655407994
# running 162 out of 500 epochs
# 0.00031454997648931265
# running 163 out of 500 epochs
# 0.00030982960955346545
# running 164 out of 500 epochs
# 0.0003056003715755651
# running 165 out of 500 epochs
# 0.0003009889502815592
# running 166 out of 500 epochs
# 0.00029707753007339005
# running 167 out of 500 epochs
# 0.00029297253483188496
# running 168 out of 500 epochs
# 0.00028875309847838554
# running 169 out of 500 epochs
# 0.00028457357287455426
# running 170 out of 500 epochs
# 0.00028055786666906596
# running 171 out of 500 epochs
# 0.0002766608104138868
# running 172 out of 500 epochs
# 0.00027296770682975574
# running 173 out of 500 epochs
# 0.0002692842105413244
# running 174 out of 500 epochs
# 0.0002654419343646926
# running 175 out of 500 epochs
# 0.00026162942352433066
# running 176 out of 500 epochs
# 0.0002587156171405998
# running 177 out of 500 epochs
# 0.00025507662333742093
# running 178 out of 500 epochs
# 0.00025114507116086315
# running 179 out of 500 epochs
# 0.00024792315631808987
# running 180 out of 500 epochs
# 0.00024502869382558856
# running 181 out of 500 epochs
# 0.00024129561582716028
# running 182 out of 500 epochs
# 0.0002384807006213426
# running 183 out of 500 epochs
# 0.00023541266940204272
# running 184 out of 500 epochs
# 0.00023216084749340857
# running 185 out of 500 epochs
# 0.00022890931510725446
# running 186 out of 500 epochs
# 0.00022665996827223958
# running 187 out of 500 epochs
# 0.00022300131301259776
# running 188 out of 500 epochs
# 0.00022032043549794858
# running 189 out of 500 epochs
# 0.00021743099872158686
# running 190 out of 500 epochs
# 0.0002143827772063863
# running 191 out of 500 epochs
# 0.00021189034699394446
# running 192 out of 500 epochs
# 0.00020912990991443317
# running 193 out of 500 epochs
# 0.00020665241875879778
# running 194 out of 500 epochs
# 0.0002040806590836534
# running 195 out of 500 epochs
# 0.00020158335003846636
# running 196 out of 500 epochs
# 0.00019940367019444238
# running 197 out of 500 epochs
# 0.0001964844605026883
# running 198 out of 500 epochs
# 0.00019405156702608414
# running 199 out of 500 epochs
# 0.000191802406940648
# running 200 out of 500 epochs
# 0.00018915119471785147
# running 201 out of 500 epochs
# 0.00018715031941004176
# running 202 out of 500 epochs
# 0.0001847274300719922
# running 203 out of 500 epochs
# 0.00018255264482528824
# running 204 out of 500 epochs
# 0.0001805516753847769
# running 205 out of 500 epochs
# 0.00017834223884468278
# running 206 out of 500 epochs
# 0.00017606822514911377
# running 207 out of 500 epochs
# 0.00017424097677576356
# running 208 out of 500 epochs
# 0.00017197693280953294
# running 209 out of 500 epochs
# 0.0001698815531199216
# running 210 out of 500 epochs
# 0.00016785077605163679
# running 211 out of 500 epochs
# 0.00016582992429903243
# running 212 out of 500 epochs
# 0.0001639977907264741
# running 213 out of 500 epochs
# 0.00016195199888594894
# running 214 out of 500 epochs
# 0.00016008012668559482
# running 215 out of 500 epochs
# 0.00015838198063041395
# running 216 out of 500 epochs
# 0.0001564306488338237
# running 217 out of 500 epochs
# 0.00015443955665735606
# running 218 out of 500 epochs
# 0.0001531236672841866
# running 219 out of 500 epochs
# 0.00015103328390371948
# running 220 out of 500 epochs
# 0.0001493698374967304
# running 221 out of 500 epochs
# 0.00014847122505064667
# running 222 out of 500 epochs
# 0.0001461621695852955
# running 223 out of 500 epochs
# 0.0001444987049884124
# running 224 out of 500 epochs
# 0.00014272105909185484
# running 225 out of 500 epochs
# 0.00014104272167969611
# running 226 out of 500 epochs
# 0.00013975663159726537
# running 227 out of 500 epochs
# 0.0001381378912507595
# running 228 out of 500 epochs
# 0.00013639997132486315
# running 229 out of 500 epochs
# 0.00013522302833735012
# running 230 out of 500 epochs
# 0.00013356954665747858
# running 231 out of 500 epochs
# 0.0001319557169760325
# running 232 out of 500 epochs
# 0.0001305653274054445
# running 233 out of 500 epochs
# 0.00012926926622943333
# running 234 out of 500 epochs
# 0.0001277001891442827
# running 235 out of 500 epochs
# 0.0001263594050821363
# running 236 out of 500 epochs
# 0.00012508819797100537
# running 237 out of 500 epochs
# 0.0001235985079498884
# running 238 out of 500 epochs
# 0.00012221305845135552
# running 239 out of 500 epochs
# 0.00012091205917386105
# running 240 out of 500 epochs
# 0.00011972026065147172
# running 241 out of 500 epochs
# 0.00011842913287788785
# running 242 out of 500 epochs
# 0.00011721746250259457
# running 243 out of 500 epochs
# 0.00011604556349690635
# running 244 out of 500 epochs
# 0.00011458564737646763
# running 245 out of 500 epochs
# 0.00011352789200221498
# running 246 out of 500 epochs
# 0.00011222189641557634
# running 247 out of 500 epochs
# 0.00011104001108227142
# running 248 out of 500 epochs
# 0.00011002200752348774
# running 249 out of 500 epochs
# 0.0001087905106942344
# running 250 out of 500 epochs
# 0.00010773769524045444
# running 251 out of 500 epochs
# 0.0001065111221881428
# running 252 out of 500 epochs
# 0.00010541864306408873
# running 253 out of 500 epochs
# 0.0001042864085623781
# running 254 out of 500 epochs
# 0.00010322866576946883
# running 255 out of 500 epochs
# 0.00010221063106049162
# running 256 out of 500 epochs
# 0.00010105853713563799
# running 257 out of 500 epochs
# 0.00010014478175435215
# running 258 out of 500 epochs
# 9.908208236690068e-05
# running 259 out of 500 epochs
# 9.80144047086166e-05
# running 260 out of 500 epochs
# 9.706586282239489e-05
# running 261 out of 500 epochs
# 9.606772331001896e-05
# running 262 out of 500 epochs
# 9.512415666298087e-05
# running 263 out of 500 epochs
# 9.414091618964449e-05
# running 264 out of 500 epochs
# 9.317748572357232e-05
# running 265 out of 500 epochs
# 9.233821735203189e-05
# running 266 out of 500 epochs
# 9.128044969960077e-05
# running 267 out of 500 epochs
# 9.042628183427344e-05
# running 268 out of 500 epochs
# 8.94181772916151e-05
# running 269 out of 500 epochs
# 8.866334125438395e-05
# running 270 out of 500 epochs
# 8.784886525366649e-05
# running 271 out of 500 epochs
# 8.690036914534478e-05
# running 272 out of 500 epochs
# 8.604618733443203e-05
# running 273 out of 500 epochs
# 8.517215610481799e-05
# running 274 out of 500 epochs
# 8.43676358878535e-05
# running 275 out of 500 epochs
# 8.354324480327098e-05
# running 276 out of 500 epochs
# 8.264934725351243e-05
# running 277 out of 500 epochs
# 8.187462071873597e-05
# running 278 out of 500 epochs
# 8.111479276825169e-05
# running 279 out of 500 epochs
# 8.026557755632287e-05
# running 280 out of 500 epochs
# 7.945609437835326e-05
# running 281 out of 500 epochs
# 7.870620091428766e-05
# running 282 out of 500 epochs
# 7.801588859971768e-05
# running 283 out of 500 epochs
# 7.724115645639056e-05
# running 284 out of 500 epochs
# 7.65260250166951e-05
# running 285 out of 500 epochs
# 7.585557614220306e-05
# running 286 out of 500 epochs
# 7.519505894985438e-05
# running 287 out of 500 epochs
# 7.438557819720397e-05
# running 288 out of 500 epochs
# 7.361581894353246e-05
# running 289 out of 500 epochs
# 7.294040309110035e-05
# running 290 out of 500 epochs
# 7.218055725388695e-05
# running 291 out of 500 epochs
# 7.156970499030042e-05
# running 292 out of 500 epochs
# 7.082973290077159e-05
# running 293 out of 500 epochs
# 7.025361901469296e-05
# running 294 out of 500 epochs
# 6.949379371690156e-05
# running 295 out of 500 epochs
# 6.884817412355915e-05
# running 296 out of 500 epochs
# 6.81975882343977e-05
# running 297 out of 500 epochs
# 6.757181942399863e-05
# running 298 out of 500 epochs
# 6.692123876443172e-05
# running 299 out of 500 epochs
# 6.635507020291698e-05
# running 300 out of 500 epochs
# 6.565979583683657e-05
# running 301 out of 500 epochs
# 6.503899491387226e-05
# running 302 out of 500 epochs
# 6.452745011150303e-05
# running 303 out of 500 epochs
# 6.388183404245258e-05
# running 304 out of 500 epochs
# 6.330573675465227e-05
# running 305 out of 500 epochs
# 6.271473012020579e-05
# running 306 out of 500 epochs
# 6.21237415430187e-05
# running 307 out of 500 epochs
# 6.152776904855273e-05
# running 308 out of 500 epochs
# 6.105595328638931e-05
# running 309 out of 500 epochs
# 6.039046638761647e-05
# running 310 out of 500 epochs
# 5.986402258410332e-05
# running 311 out of 500 epochs
# 5.929785500787451e-05
# running 312 out of 500 epochs
# 5.875651739491635e-05
# running 313 out of 500 epochs
# 5.824497232727784e-05
# running 314 out of 500 epochs
# 5.773342551644115e-05
# running 315 out of 500 epochs
# 5.718712153187274e-05
# running 316 out of 500 epochs
# 5.669545161405646e-05
# running 317 out of 500 epochs
# 5.617892990509669e-05
# running 318 out of 500 epochs
# 5.566739112812987e-05
# running 319 out of 500 epochs
# 5.513101314136293e-05
# running 320 out of 500 epochs
# 5.4634365369565785e-05
# running 321 out of 500 epochs
# 5.424697640895223e-05
# running 322 out of 500 epochs
# 5.3715571160258456e-05
# running 323 out of 500 epochs
# 5.321891353560204e-05
# running 324 out of 500 epochs
# 5.274710436727522e-05
# running 325 out of 500 epochs
# 5.227529322837654e-05
# running 326 out of 500 epochs
# 5.177367377958338e-05
# running 327 out of 500 epochs
# 5.139125369169051e-05
# running 328 out of 500 epochs
# 5.087473975133131e-05
# running 329 out of 500 epochs
# 5.042278712608095e-05
# running 330 out of 500 epochs
# 4.996089758909269e-05
# running 331 out of 500 epochs
# 4.954867138925086e-05
# running 332 out of 500 epochs
# 4.907685835557155e-05
# running 333 out of 500 epochs
# 4.8634837677733835e-05
# running 334 out of 500 epochs
# 4.823750987270614e-05
# running 335 out of 500 epochs
# 4.779549090017099e-05
# running 336 out of 500 epochs
# 4.7363397698063636e-05
# running 337 out of 500 epochs
# 4.700084180816096e-05
# running 338 out of 500 epochs
# 4.655881957660313e-05
# running 339 out of 500 epochs
# 4.615652824213612e-05
# running 340 out of 500 epochs
# 4.5798936791167456e-05
# running 341 out of 500 epochs
# 4.538671403982638e-05
# running 342 out of 500 epochs
# 4.496455428200837e-05
# running 343 out of 500 epochs
# 4.459206009717794e-05
# running 344 out of 500 epochs
# 4.4244396121939644e-05
# running 345 out of 500 epochs
# 4.381230951366888e-05
# running 346 out of 500 epochs
# 4.3449748242589216e-05
# running 347 out of 500 epochs
# 4.307725134822249e-05
# running 348 out of 500 epochs
# 4.27295922236226e-05
# running 349 out of 500 epochs
# 4.240675790849006e-05
# running 350 out of 500 epochs
# 4.1959769987442996e-05
# running 351 out of 500 epochs
# 4.164190697035034e-05
# running 352 out of 500 epochs
# 4.125948006124721e-05
# running 353 out of 500 epochs
# 4.0891951584853814e-05
# running 354 out of 500 epochs
# 4.0514487560964575e-05
# running 355 out of 500 epochs
# 4.021648790815865e-05
# running 356 out of 500 epochs
# 3.989862386788445e-05
# running 357 out of 500 epochs
# 3.9501296744977786e-05
# running 358 out of 500 epochs
# 3.9218195979628945e-05
# running 359 out of 500 epochs
# 3.885563160110905e-05
# running 360 out of 500 epochs
# 3.849306911736979e-05
# running 361 out of 500 epochs
# 3.819506840348671e-05
# running 362 out of 500 epochs
# 3.7872237858967615e-05
# running 363 out of 500 epochs
# 3.7559338882905045e-05
# running 364 out of 500 epochs
# 3.7246438523652614e-05
# running 365 out of 500 epochs
# 3.69434733329399e-05
# running 366 out of 500 epochs
# 3.6585873507040865e-05
# running 367 out of 500 epochs
# 3.630773987121453e-05
# running 368 out of 500 epochs
# 3.5974975768719254e-05
# running 369 out of 500 epochs
# 3.569187257805121e-05
# running 370 out of 500 epochs
# 3.5423671458071716e-05
# running 371 out of 500 epochs
# 3.510580821360539e-05
# running 372 out of 500 epochs
# 3.480283949860071e-05
# running 373 out of 500 epochs
# 3.44998728110113e-05
# running 374 out of 500 epochs
# 3.424160202788092e-05
# running 375 out of 500 epochs
# 3.3933669783436926e-05
# running 376 out of 500 epochs
# 3.365553493495099e-05
# running 377 out of 500 epochs
# 3.3402233915088196e-05
# running 378 out of 500 epochs
# 3.307939766727941e-05
# running 379 out of 500 epochs
# 3.283106214742778e-05
# running 380 out of 500 epochs
# 3.251815883231757e-05
# running 381 out of 500 epochs
# 3.227479207149978e-05
# running 382 out of 500 epochs
# 3.2001622268277664e-05
# running 383 out of 500 epochs
# 3.1788052221296916e-05
# running 384 out of 500 epochs
# 3.1519852351872636e-05
# running 385 out of 500 epochs
# 3.1241715343336786e-05
# running 386 out of 500 epochs
# 3.101821111310225e-05
# running 387 out of 500 epochs
# 3.0675509606226115e-05
# running 388 out of 500 epochs
# 3.0442072556979838e-05
# running 389 out of 500 epochs
# 3.020367023509607e-05
# running 390 out of 500 epochs
# 2.997023163212968e-05
# running 391 out of 500 epochs
# 2.972686365865229e-05
# running 392 out of 500 epochs
# 2.948349469988898e-05
# running 393 out of 500 epochs
# 2.92301916336631e-05
# running 394 out of 500 epochs
# 2.899675375071335e-05
# running 395 out of 500 epochs
# 2.875834949615334e-05
# running 396 out of 500 epochs
# 2.8534845455396862e-05
# running 397 out of 500 epochs
# 2.8316308240997994e-05
# running 398 out of 500 epochs
# 2.8063003583156387e-05
# running 399 out of 500 epochs
# 2.7839501323493703e-05
# running 400 out of 500 epochs
# 2.7611030721648906e-05
# running 401 out of 500 epochs
# 2.7397458438827016e-05
# running 402 out of 500 epochs
# 2.7149121441046493e-05
# running 403 out of 500 epochs
# 2.693555059825788e-05
# running 404 out of 500 epochs
# 2.669217928996659e-05
# running 405 out of 500 epochs
# 2.653324080862755e-05
# running 406 out of 500 epochs
# 2.628987131932566e-05
# running 407 out of 500 epochs
# 2.6086232272367244e-05
# running 408 out of 500 epochs
# 2.5857760628393105e-05
# running 409 out of 500 epochs
# 2.5644188629788307e-05
# running 410 out of 500 epochs
# 2.5445518626080837e-05
# running 411 out of 500 epochs
# 2.5276646624661225e-05
# running 412 out of 500 epochs
# 2.5038242531157568e-05
# running 413 out of 500 epochs
# 2.4864405493948045e-05
# running 414 out of 500 epochs
# 2.4660767072267237e-05
# running 415 out of 500 epochs
# 2.4472028599120677e-05
# running 416 out of 500 epochs
# 2.431805641360067e-05
# running 417 out of 500 epochs
# 2.4074684404240543e-05
# running 418 out of 500 epochs
# 2.3866079118306516e-05
# running 419 out of 500 epochs
# 2.3677341535706848e-05
# running 420 out of 500 epochs
# 2.3508470197460458e-05
# running 421 out of 500 epochs
# 2.3349531943495094e-05
# running 422 out of 500 epochs
# 2.3121059105809156e-05
# running 423 out of 500 epochs
# 2.294225483486419e-05
# running 424 out of 500 epochs
# 2.280318360211216e-05
# running 425 out of 500 epochs
# 2.2564777282241266e-05
# running 426 out of 500 epochs
# 2.2395904636596242e-05
# running 427 out of 500 epochs
# 2.2231999726803526e-05
# running 428 out of 500 epochs
# 2.2063127895914175e-05
# running 429 out of 500 epochs
# 2.1884322971269892e-05
# running 430 out of 500 epochs
# 2.1710485043513472e-05
# running 431 out of 500 epochs
# 2.1541612909459218e-05
# running 432 out of 500 epochs
# 2.1377707431232313e-05
# running 433 out of 500 epochs
# 2.121876840040689e-05
# running 434 out of 500 epochs
# 2.1044929515786254e-05
# running 435 out of 500 epochs
# 2.0871091313286645e-05
# running 436 out of 500 epochs
# 2.072705187098715e-05
# running 437 out of 500 epochs
# 2.0558180343262695e-05
# running 438 out of 500 epochs
# 2.040420830932514e-05
# running 439 out of 500 epochs
# 2.0225401878330256e-05
# running 440 out of 500 epochs
# 2.005156253896227e-05
# running 441 out of 500 epochs
# 1.99025578808687e-05
# running 442 out of 500 epochs
# 1.9753552389071654e-05
# running 443 out of 500 epochs
# 1.9599581226733182e-05
# running 444 out of 500 epochs
# 1.9445608434883372e-05
# running 445 out of 500 epochs
# 1.9286668248241767e-05
# running 446 out of 500 epochs
# 1.913269630904324e-05
# running 447 out of 500 epochs
# 1.9018459189131438e-05
# running 448 out of 500 epochs
# 1.8854553559322085e-05
# running 449 out of 500 epochs
# 1.871548183392709e-05
# running 450 out of 500 epochs
# 1.8546607350344857e-05
# running 451 out of 500 epochs
# 1.8427403707240348e-05
# running 452 out of 500 epochs
# 1.829329943348057e-05
# running 453 out of 500 epochs
# 1.813932688795224e-05
# running 454 out of 500 epochs
# 1.796548512326505e-05
# running 455 out of 500 epochs
# 1.7846281101204415e-05
# running 456 out of 500 epochs
# 1.774694438457421e-05
# running 457 out of 500 epochs
# 1.7583037750531123e-05
# running 458 out of 500 epochs
# 1.745886616314844e-05
# running 459 out of 500 epochs
# 1.7294958809088712e-05
# running 460 out of 500 epochs
# 1.717078750592312e-05
# running 461 out of 500 epochs
# 1.707641687668608e-05
# running 462 out of 500 epochs
# 1.6917477732173818e-05
# running 463 out of 500 epochs
# 1.6803239001698483e-05
# running 464 out of 500 epochs
# 1.665423246777209e-05
# running 465 out of 500 epochs
# 1.6525094035083992e-05
# running 466 out of 500 epochs
# 1.640588908458085e-05
# running 467 out of 500 epochs
# 1.6261849320168647e-05
# running 468 out of 500 epochs
# 1.6142643611753254e-05
# running 469 out of 500 epochs
# 1.604827271724692e-05
# running 470 out of 500 epochs
# 1.5924101650928908e-05
# running 471 out of 500 epochs
# 1.5789995681340468e-05
# running 472 out of 500 epochs
# 1.567079050346365e-05
# running 473 out of 500 epochs
# 1.555158534453464e-05
# running 474 out of 500 epochs
# 1.5432379692962666e-05
# running 475 out of 500 epochs
# 1.5308207044502826e-05
# running 476 out of 500 epochs
# 1.5193968768774843e-05
# running 477 out of 500 epochs
# 1.5079729943560475e-05
# running 478 out of 500 epochs
# 1.4940657526570552e-05
# running 479 out of 500 epochs
# 1.4871121209125704e-05
# running 480 out of 500 epochs
# 1.4717146996190422e-05
# running 481 out of 500 epochs
# 1.4607875148916113e-05
# running 482 out of 500 epochs
# 1.449860428692773e-05
# running 483 out of 500 epochs
# 1.4389332022801682e-05
# running 484 out of 500 epochs
# 1.4304894079941732e-05
# running 485 out of 500 epochs
# 1.4205556681190501e-05
# running 486 out of 500 epochs
# 1.408138435484337e-05
# running 487 out of 500 epochs
# 1.3967145510681197e-05
# running 488 out of 500 epochs
# 1.3857872943390248e-05
# running 489 out of 500 epochs
# 1.3758534729883346e-05
# running 490 out of 500 epochs
# 1.3669130491204365e-05
# running 491 out of 500 epochs
# 1.3559858681825668e-05
# running 492 out of 500 epochs
# 1.3450586758760133e-05
# running 493 out of 500 epochs
# 1.334628179468685e-05
# running 494 out of 500 epochs
# 1.3251910615963425e-05
# running 495 out of 500 epochs
# 1.315257221297846e-05
# running 496 out of 500 epochs
# 1.3038333056177484e-05
# running 497 out of 500 epochs
# 1.2973763314031809e-05
# running 498 out of 500 epochs
# 1.2864491282016388e-05
# running 499 out of 500 epochs
# 1.277508692965057e-05
# running 500 out of 500 epochs
# 1.270554967428931e-05

# %%
def input_prep(text,voca):
    tokens = tokenizer(text)
    x_test = embed(voca,tokens)
    return x_test

# %%
model = Model(input_size,20,10,out_size)
state = torch.load('med_bot.pth')
model.load_state_dict(state)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## testing

# %%
import random
bot = 'Medbot'
print("let's have a convo, (to exit type 'quit' )")
with torch.no_grad():
    model.eval()
    while True:
        text = input('You:')
        if text == 'quit':
            print('Nice ')
            break
        x_test = input_prep(text,voca)
        x_test = torch.tensor(x_test,dtype=torch.float)
        x_test = x_test.view(1,-1)
        out = model.forward(x_test)
        _,pred = torch.max(out,1)
        tag = tags[pred.item()]
        for intent in chats['intents']:
                if tag == intent['tag']:
                    print(f'You: {text}')
                    print(f"{bot}: {random.choice(intent['responses'])}")
# Out:
# let's have a convo, (to exit type 'quit' )
# You: good day
# Medbot: Hello, thanks for visiting
# You: I don't feel well today
# Medbot: Do you have any symtoms
# You: I have temperature and nausea
# Medbot: Symtoms can be sign of multiple things, to diagnosis we need some tests. Do you want an anppointment booked ?
# You: yes please
# Medbot: okay, it has been done for you!
# You: thanks
# Medbot: My pleasure
